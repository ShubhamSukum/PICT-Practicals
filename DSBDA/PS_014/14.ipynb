# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.metrics import accuracy_score

# %%
DataFrame=pd.read_csv('Iris.csv')
DataFrame
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
DataFrame1=DataFrame.drop('class',axis=1)
DataFrame1
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# ...

# %% [markdown]
# # 1

# %%
DataFrame.isna().sum()
# Out:
# sepal length in cm    0
# sepal width in cm     0
# petal length in cm    0
# petal width in cm     0
# class                 0
# dtype: int64

# %%
DataFrame.dropna(inplace=True)
DataFrame
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
DataFrame.replace('?',pd.NA,inplace=True)
DataFrame
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
print(DataFrame.head())
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
DataFrame['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # 2

# %%
z_val=np.abs((DataFrame1-DataFrame1.mean())/DataFrame.std())
out=z_val >3
DataFrame1=DataFrame1[~out.any(axis=1)]
DataFrame1
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15760\2548455214.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   z_val=np.abs((DataFrame1-DataFrame1.mean())/DataFrame.std())
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# ...

# %% [markdown]
# # 3

# %%
Scaler=StandardScaler()
DataFrame=Scalar.fit_transform(DataFrame1)
DataFrame
# Out:
# array([[-0.89892658,  1.08537392, -1.35289577, -1.32051128],
#        [-1.14047763, -0.10725672, -1.35289577, -1.32051128],
#        [-1.38202868,  0.36979554, -1.40988799, -1.32051128],
#        [-1.50280421,  0.13126941, -1.29590355, -1.32051128],
#        [-1.0197021 ,  1.32390005, -1.35289577, -1.32051128],
#        [-0.53659999,  2.03947844, -1.18191912, -1.05746826],
#        [-1.50280421,  0.8468478 , -1.35289577, -1.18898977],
#        [-1.0197021 ,  0.8468478 , -1.29590355, -1.32051128],
#        [-1.74435527, -0.34578284, -1.35289577, -1.32051128],
#        [-1.14047763,  0.13126941, -1.29590355, -1.45203279],
#        [-0.53659999,  1.56242618, -1.29590355, -1.32051128],
#        [-1.26125316,  0.8468478 , -1.23891134, -1.32051128],
#        [-1.26125316, -0.10725672, -1.35289577, -1.45203279],
#        [-1.86513079, -0.10725672, -1.52387242, -1.45203279],
#        [-0.05349788,  2.27800456, -1.4668802 , -1.32051128],
# ...

# %% [markdown]
# # 4

# %%
X=DataFrame.drop('class',axis=1)
Y=DataFrame['class']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=46)

# %%
reg=LogisticRegression()
reg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
a1=reg.predict(X_test)

# %%
nvb=MultinomialNB()
nvb.fit(X_train,Y_train)
# Out:
# MultinomialNB()

# %%
nvbg=GaussianNB()
nvbg.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
a2=nvb.predict(X_test)

# %%
a3=nvbg.predict(X_test)

# %%
z1=accuracy_score(Y_test,a1)
z2=accuracy_score(Y_test,a2)
z3=accuracy_score(Y_test,a3)

# %%
print(z1)
print(z2)
print(z3)
# Out:
# 0.9
# 0.9
# 0.8666666666666667

# %% [markdown]
# # end

# %% [markdown]
# # EXTRA

# %%
DataFrame3=pd.read_csv('Iris.csv')
DataFrame3
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %%
DataFrame3.loc[DataFrame3['class']=='Iris-setosa','class']=1
DataFrame3.loc[DataFrame3['class']=='Iris-versicolor','class']=2
DataFrame3.loc[DataFrame3['class']=='Iris-virginica','class']=3
