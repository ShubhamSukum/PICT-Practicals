# %%
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sns

# %%
cols=["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","num"]
df=pd.read_csv('Cleavland.csv')
df.columns=cols
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 1    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 2    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 3    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 4    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 298  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 299  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 300  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 301  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 0      2.0  3.0  3.0    2
# ...

# %%
df=df.replace("?",pd.NA)
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 1    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 2    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 3    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 4    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 298  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 299  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 300  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 301  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope    ca thal  num
# 0      2.0   3.0  3.0    2
# ...

# %%
df=df.dropna()
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 1    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 2    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 3    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 4    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 296  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 297  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 298  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 299  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 300  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca thal  num
# 0      2.0  3.0  3.0    2
# ...

# %%
df.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# num           int64
# dtype: object

# %%
df=df.astype(float)
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 1    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 2    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 3    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 4    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 296  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 297  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 298  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 299  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 300  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  num
# 0      2.0  3.0   3.0  2.0
# ...

# %%
col=['trestbps','thal','thalach']
df[col].hist(bins=10)
plt.show()

# %%
col=['trestbps','thal','thalach']
plt.plot(df[col[0]],df[col[1]],'ro')
plt.show()

# %%
col=['trestbps']
plt.figure(figsize=(15,10))
df[col].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='trestbps'>

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 1    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 2    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 3    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 4    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 5    62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# 6    57.0  0.0  4.0     120.0  354.0  0.0      0.0    163.0    1.0      0.6
# 7    63.0  1.0  4.0     130.0  254.0  0.0      2.0    147.0    0.0      1.4
# 8    53.0  1.0  4.0     140.0  203.0  1.0      2.0    155.0    1.0      3.1
# 9    57.0  1.0  4.0     140.0  192.0  0.0      0.0    148.0    0.0      0.4
# 10   56.0  0.0  2.0     140.0  294.0  0.0      2.0    153.0    0.0      1.3
# ...

# %%
sns.lineplot?

# %%
col=['trestbps','thal']
sns.lineplot(df,x=df[col[0]],y=df[col[1]])
mat.show()

# %%
mat.scatter?

# %%
col=['trestbps','thal']
mat.scatter(x=df[col[0]],y=df[col[1]],marker='*')
mat.show()

# %%
sns.scatterplot?

# %%
col=['trestbps','thal']
sns.scatterplot?

# %%
sns.scatterplot(df,x=col[0],y=col[1])
mat.show()

# %%
sns.boxplot?

# %%
sns.boxplot(df,x=col[0],y=col[1])
mat.show()

# %%
mat.pie?

# %%
val=df['thal'].value_counts()
mat.pie(val,labels=val.index,autopct='%1.1f%%')
mat.show()

# %%
df['thal'].unique()
# Out:
# array([3., 7., 6.])
